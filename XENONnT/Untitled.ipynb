# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Define boundaries
#       2 J_bdr_marker = mfem.intArray()
# ----> 3 J_bdr_marker.SetSize(pmesh.bdr_attributes.Max())
#       4 J_bdr_marker.Assign(0)
#       5 J_bdr_marker[0] = 0 # port 1
#
# NameError: name 'pmesh' is not defined
